# %%
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt

# 1. Connect to PostgreSQL using your DBeaver credentials
conn = psycopg2.connect(
    host="localhost", 
    database="eves_apple", 
    user="postgres", 
    password="SashaKarina2!", 
    port="5432"

    
)

# 2. Extract your data
query = "SELECT category, COUNT(*) as total FROM enclosure_event GROUP BY category ORDER BY total DESC;"
df = pd.read_sql_query(query, conn)


# 3. Display the visual chart directly inside your code editor
df.plot(x='category', y='total', kind='bar', figsize=(10, 5))
plt.title("My PostgreSQL Data Chart")
plt.show()
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_29004\537409154.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
# 1. Connect to PostgreSQL using your DBeaver credentials
conn = psycopg2.connect(
    host="localhost", 
    database="eves_apple", 
    user="postgres", 
    password="SashaKarina2!", 
    port="5432"
)

query_surveillence = "SELECT year, SUM(scale_millions_users) as total_users_affected FROM surveillance_escalation GROUP BY year ORDER BY year;"
df_surveillance = pd.read_sql_query(query_surveillence, conn)

df_surveillance.plot(x='year', y='total_users_affected', kind='line', marker='o', figsize=(10, 5))
plt.title("Surveillance Escalation Over Time")
plt.xlabel("Year")
plt.ylabel("Total Users Affected (Millions)")
plt.show()

query_enclosure = "SELECT category, COUNT(*) as total FROM enclosure_event GROUP BY category ORDER BY total DESC;"
df_enclosure = pd.read_sql_query(query_enclosure, conn)

df_enclosure.plot(x='category', y='total', kind='bar', figsize=(10, 5))
plt.title("Enclosure Escalation Over Time")
plt.xlabel("Year")
plt.ylabel("Total Users Affected (Millions)")
plt.show()
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_29004\2839451371.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_surveillance = pd.read_sql_query(query_surveillence, conn)
# C:\Users\aleks\AppData\Local\Temp\ipykernel_29004\2839451371.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_enclosure = pd.read_sql_query(query_enclosure, conn)
